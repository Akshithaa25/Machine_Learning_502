# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshithaa25/Machine_Learning_502/blob/main/2348502_WineQuality_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-628810e3-87c6-4fcb-8a66-ae3cddf9cef3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-628810e3-87c6-4fcb-8a66-ae3cddf9cef3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("WineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# Checking for missing values

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %% [markdown]
# To describe the statistical analysis of the dataset

# %%
df.shape
# size of the dataset
# Out:
# (1143, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
#  13  wine_category         1143 non-null   object
# dtypes: float64(11), int64(2), object(1)
# ...

# %% [markdown]
# This dataset has only float and integer values

# %% [markdown]
# Removing outliers

# %%
df.boxplot()
plt.figure(figsize=(10,10))
plt.show()

# %%
'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality'

# %%
sns.boxplot(y='volatile acidity', data=df)
# Out:
# <Axes: ylabel='volatile acidity'>

# %%
df1=df[df['volatile acidity']<1.0]

# %%
sns.boxplot(y='volatile acidity', data=df1)
# Out:
# <Axes: ylabel='volatile acidity'>

# %%
sns.boxplot(y='fixed acidity', data=df)
# Out:
# <Axes: ylabel='fixed acidity'>

# %%
df1=df[df['fixed acidity']<11]
sns.boxplot(y='fixed acidity', data=df1)
# Out:
# <Axes: ylabel='fixed acidity'>

# %%
sns.boxplot(y='citric acid', data=df)
# Out:
# <Axes: ylabel='citric acid'>

# %%
df1=df[df['citric acid']<1.0]
sns.boxplot(y='citric acid', data=df1)
# Out:
# <Axes: ylabel='citric acid'>

# %% [markdown]
# Histogram for the dataset

# %%
df.hist(figsize=(20,20), color='red')
plt.show()

# %% [markdown]
# Alcohol has the maximum correlation with quality followed by sulphates and citric acid and then fixed acidity

# %%
# Checking For Correlation
mycor= df.corr()
plt.subplots(figsize=(12,12)) #INCREASE HEATMAP SIZE
sns.heatmap(mycor,annot=True)
# Out:
# <ipython-input-62-935c45e0743e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mycor= df.corr()
# <Axes: >

# %%
sns.jointplot(x='quality',y='alcohol',data=df,kind='scatter')
